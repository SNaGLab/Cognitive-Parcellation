# %%
#To hide warnings export PYTHONWARNINGS="ignore"
#Imports{

import os
from os.path import dirname
from os.path import join
os.environ['KERAS_BACKEND'] = 'theano'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' #Cha


import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
import cPickle as pickle
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.misc import imread
from scipy.misc import imresize
from scipy.io import loadmat

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, MaxPooling2D, Input, ZeroPadding2D,merge,Lambda
from keras.layers.convolutional import Convolution2D
from keras.models import Model
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.optimizers import SGD
from keras import backend as K
from keras.engine import Layer
from keras.layers.core import Lambda
from keras.utils.vis_utils import plot_model
from keras.layers.core import  Lambda
from keras.regularizers import l2
#}
# Out:
# Using Theano backend.

# %%
#Code snippet needed to read activation values from each layer of the pre-trained artificial neural networks
def get_activations(model, layer, X_batch):
    #keras.backend.function(inputs, outputs, updates=None)
    get_activations = K.function([model.layers[0].input, K.learning_phase()], [model.layers[layer].output,])
    #The learning phase flag is a bool tensor (0 = test, 1 = train)
    activations = get_activations([X_batch,0])
    return activations

# %%
#Function to pre-process the input image to ensure uniform size and color
def preprocess_image_batch(image_paths, img_size=None, crop_size=None, color_mode='rgb', out=None):
    """
    Consistent preprocessing of images batches
    :param image_paths: iterable: images to process
    :param crop_size: tuple: crop images if specified
    :param img_size: tuple: resize images if specified
    :param color_mode: Use rgb or change to bgr mode based on type of model you want to use
    :param out: append output to this iterable if specified
    """
    img_list = []

    for im_path in image_paths:
        img = imread(im_path, mode='RGB')
        #print im_path
        #print img.shape
        if img_size:
            img = imresize(img, img_size)

        img = img.astype('float32')
        # We normalize the colors (in RGB space) with the empirical means on the training set
        img[:, :, 0] -= 123.68
        img[:, :, 1] -= 116.779
        img[:, :, 2] -= 103.939
        # We permute the colors to get them in the BGR order
        if color_mode == 'bgr':
            img[:, :, [0, 1, 2]] = img[:, :, [2, 1, 0]]
        img = img.transpose((2, 0, 1))

        if crop_size:
            img = img[:, (img_size[0] - crop_size[0]) // 2:(img_size[0] + crop_size[0]) // 2
            , (img_size[1] - crop_size[1]) // 2:(img_size[1] + crop_size[1]) // 2]

        img_list.append(img)

    try:
        img_batch = np.stack(img_list, axis=0)
    except:
        print im_path
        raise ValueError('when img_size and crop_size are None, images'
                ' in image_paths must have the same shapes.')

    if out is not None and hasattr(out, 'append'):
        out.append(img_batch)
    else:
        return img_batch

# %%
#Helper function to normalization across channels
K.set_image_dim_ordering('th')
def crosschannelnormalization(alpha=1e-4, k=2, beta=0.75, n=5, **kwargs):
    """
    This is the function used for cross channel normalization in the original
    Alexnet
    """
    def f(X):
        if K.image_dim_ordering()=='tf':
            b, r, c, ch = X.get_shape()
        else:
            b, ch, r, c = X.shape

        half = n // 2
        square = K.square(X)
        scale = k
        if K.image_dim_ordering() == 'th':
            extra_channels = K.spatial_2d_padding(K.permute_dimensions(square, (0, 2, 3, 1)), ((0,0),(half,half)))
            extra_channels = K.permute_dimensions(extra_channels, (0, 3, 1, 2))
            for i in range(n):
                scale += alpha * extra_channels[:, i:i+ch, :, :]
        if K.image_dim_ordering() == 'tf':
            extra_channels = K.spatial_2d_padding(K.permute_dimensions(square, (0, 3, 1, 2)), (half, 0))
            extra_channels = K.permute_dimensions(extra_channels, (0, 2, 3, 1))
            for i in range(n):
                scale += alpha * extra_channels[:, :, :, i:i+int(ch)]
        scale = scale ** beta
        return X / scale


    return Lambda(f, output_shape=lambda input_shape: input_shape, **kwargs)

# %%
#Helper Function to split tensor
def splittensor(axis=1, ratio_split=1, id_split=0, **kwargs):
    def f(X):
        div = K.shape(X)[axis] // ratio_split

        if axis == 0:
            output = X[id_split*div:(id_split+1)*div, :, :, :]
        elif axis == 1:
            output = X[:, id_split*div:(id_split+1)*div, :, :]
        elif axis == 2:
            output = X[:, :, id_split*div:(id_split+1)*div, :]
        elif axis == 3:
            output = X[:, :, :, id_split*div:(id_split+1)*div]
        else:
            raise ValueError("This axis is not possible")
        return output

    def g(input_shape):
        output_shape = list(input_shape)
        output_shape[axis] = output_shape[axis] // ratio_split
        return tuple(output_shape)


    return Lambda(f, output_shape=lambda input_shape: g(input_shape), **kwargs)

# %%
#Alexnet layer architecture class
def AlexNet(img_shape=(3, 227, 227), n_classes=1000, l2_reg=0.,weights_path=None):

    dim_ordering = K.image_dim_ordering()
    print dim_ordering
    if dim_ordering == 'th':
        batch_index = 0
        channel_index = 1
        row_index = 2
        col_index = 3
    if dim_ordering == 'tf':
        batch_index = 0
        channel_index = 3
        row_index = 1
        col_index = 2

    inputs = Input(img_shape)

    conv_1 = Convolution2D(96, 11, 11, subsample=(4, 4), activation='relu',
                           name='conv_1', W_regularizer=l2(l2_reg))(inputs)

    conv_1_mask = np.ones(shape=((96, 55, 55)))
    conv_1_mask  = K.variable(conv_1_mask)
    conv_1_lambda = Lambda(lambda x: x * conv_1_mask)(conv_1)

    conv_2 = MaxPooling2D((3, 3), strides=(2, 2))(conv_1_lambda)
    conv_2 = crosschannelnormalization(name="convpool_1")(conv_2)
    conv_2 = ZeroPadding2D((2, 2))(conv_2)
    conv_2 = merge([
        Convolution2D(128, 5, 5, activation="relu", name='conv_2_'+str(i+1),
                      W_regularizer=l2(l2_reg))(
            splittensor(axis=channel_index, ratio_split=2, id_split=i)(conv_2)
        ) for i in range(2)], mode='concat', concat_axis=channel_index, name="conv_2")

    conv_2_mask = np.ones(shape=((256, 27, 27)))
    conv_2_mask = K.variable(conv_2_mask)
    conv_2_lambda = Lambda(lambda x: x * conv_2_mask)(conv_2)

    conv_3 = MaxPooling2D((3, 3), strides=(2, 2))(conv_2_lambda)
    conv_3 = crosschannelnormalization()(conv_3)
    conv_3 = ZeroPadding2D((1, 1))(conv_3)
    conv_3 = Convolution2D(384, 3, 3, activation='relu', name='conv_3',
                           W_regularizer=l2(l2_reg))(conv_3)

    conv_3_mask = np.ones(shape=((384, 13, 13)))
    conv_3_mask = K.variable(conv_3_mask)
    conv_3_lambda = Lambda(lambda x: x * conv_3_mask)(conv_3)

    conv_4 = ZeroPadding2D((1, 1))(conv_3_lambda)
    conv_4 = merge([
        Convolution2D(192, 3, 3, activation="relu", name='conv_4_'+str(i+1),
                      W_regularizer=l2(l2_reg))(
            splittensor(axis=channel_index, ratio_split=2, id_split=i)(conv_4)
        ) for i in range(2)], mode='concat', concat_axis=channel_index, name="conv_4")

    conv_4_mask = np.ones(shape=((384, 13, 13)))
    conv_4_mask = K.variable(conv_4_mask)
    conv_4_lambda = Lambda(lambda x: x * conv_4_mask)(conv_4)

    conv_5 = ZeroPadding2D((1, 1))(conv_4_lambda)
    conv_5 = merge([
        Convolution2D(128, 3, 3, activation="relu", name='conv_5_'+str(i+1),
                      W_regularizer=l2(l2_reg))(
            splittensor(axis=channel_index, ratio_split=2, id_split=i)(conv_5)
        ) for i in range(2)], mode='concat', concat_axis=channel_index, name="conv_5")

    conv_5_mask = np.ones(shape=((256, 13, 13)))
    conv_5_mask = K.variable(conv_5_mask)
    conv_5_lambda = Lambda(lambda x: x * conv_5_mask)(conv_5)

    dense_1 = MaxPooling2D((3, 3), strides=(2, 2), name="convpool_5")(conv_5_lambda)

    dense_1 = Flatten(name="flatten")(dense_1)
    dense_1 = Dense(4096, activation='relu', name='dense_1',
                    W_regularizer=l2(l2_reg))(dense_1)

    dense_1_mask = np.ones(shape=((4096,)))
    dense_1_mask = K.variable(dense_1_mask)
    dense_1_lambda = Lambda(lambda x: x * dense_1_mask)(dense_1)

    dense_2 = Dropout(0.5)(dense_1_lambda)
    dense_2 = Dense(4096, activation='relu', name='dense_2',
                    W_regularizer=l2(l2_reg))(dense_2)

    dense_2_mask = np.ones(shape=((4096,)))
    dense_2_mask = K.variable(dense_2_mask)
    dense_2_lambda = Lambda(lambda x: x * dense_2_mask)(dense_2)

    dense_3 = Dropout(0.5)(dense_2_lambda)
    if n_classes == 1000:
        dense_3 = Dense(n_classes, name='dense_3',
                        W_regularizer=l2(l2_reg))(dense_3)
        dense_3_mask = np.ones(shape=((1000,)))
        dense_3_mask = K.variable(dense_3_mask)
        dense_3_lambda = Lambda(lambda x: x * dense_3_mask)(dense_3)
    else:
        # We change the name so when loading the weights_file from a
        # Imagenet pretrained model does not crash
        dense_3 = Dense(n_classes, name='dense_3_new',
                        W_regularizer=l2(l2_reg))(dense_3)
        dense_3_mask = np.ones(shape=((1000,)))
        dense_3_mask = K.variable(dense_3_mask)
        dense_3_lambda = Lambda(lambda x: x * dense_3_mask)(dense_3)

    prediction = Activation("softmax", name="softmax")(dense_3_lambda)

    model = Model(input=inputs, output=prediction)
    if weights_path:
        model.load_weights(weights_path)

    return model

# %%
#Load the details of all the 1000 classes and the function to conver the synset id to words{
meta_clsloc_file = '../../data/meta_clsloc.mat'
synsets = loadmat(meta_clsloc_file)['synsets'][0]
synsets_imagenet_sorted = sorted([(int(s[0]), str(s[1][0])) for s in synsets[:1000]],key=lambda v: v[1])
corr = {}
for j in range(1000):
    corr[synsets_imagenet_sorted[j][0]] = j

corr_inv = {}
for j in range(1, 1001):
    corr_inv[corr[j]] = j

def id_to_words(id_):
    return synsets[corr_inv[id_] - 1][2][0]

def pprint_output(out, n_max_synsets=10):
    wids = []
    best_ids = out.argsort()[::-1][:n_max_synsets]
    for u in best_ids:
        wids.append(str(synsets[corr_inv[u] - 1][1][0]))
        print('%.2f' % round(100 * out[u], 2) + ' : ' + id_to_words(u)+' '+ str(synsets[corr_inv[u] - 1][1][0]))
    return wids

# %%
#Some Config

p = 'animate'
url_path = '../../data/92_image/'+p+'/'

# %%
# Prepare the image list and pre-process them{
im_list = []
for i in os.listdir(url_path):
    if not i.startswith('~') and not i.startswith('.'):
        temp = i.split('.')[0]
        im_list.append(url_path+i)

im = preprocess_image_batch(im_list,img_size=(256,256), crop_size=(227,227), color_mode="rgb")
#}

# %%
id_to_words(1)
# Out:
# u'goldfish, Carassius auratus'

# %%
# Model parmeters and running the model from the loaded weights{

out_r = []

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model = AlexNet(weights_path="../../data/weights/alexnet_weights.h5")
model.compile(optimizer=sgd, loss='mse')

out = model.predict(im,batch_size=64)

predicted_valid_wids = []
for i in range(len(im_list)):
    print im_list[i], pprint_output(out[i])
    predicted_valid_wids.append(pprint_output(out[i]))
#}
# Out:
# th
# ../../data/92_image/animate/12.jpeg 2.71 : nematode, nematode worm, roundworm n01930112
# 2.01 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 1.75 : sea lion n02077923
# 1.59 : plane, carpenter's plane, woodworking plane n03954731
# 1.23 : mink n02442845
# 1.13 : weasel n02441942
# 1.12 : nipple n03825788
# 1.04 : dugong, Dugong dugon n02074367
# 0.91 : clog, geta, patten, sabot n03047690
# 0.88 : tub, vat n04493381
# ['n01930112', 'n01873310', 'n02077923', 'n03954731', 'n02442845', 'n02441942', 'n03825788', 'n02074367', 'n03047690', 'n04493381']
# 2.71 : nematode, nematode worm, roundworm n01930112
# 2.01 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 1.75 : sea lion n02077923
# 1.59 : plane, carpenter's plane, woodworking plane n03954731
# 1.23 : mink n02442845
# 1.13 : weasel n02441942
# 1.12 : nipple n03825788
# 1.04 : dugong, Dugong dugon n02074367
# 0.91 : clog, geta, patten, sabot n03047690
# 0.88 : tub, vat n04493381
# ../../data/92_image/animate/34.jpeg 10.71 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 3.62 : marmoset n02490219
# 2.35 : frilled lizard, Chlamydosaurus kingi n01688243
# 2.02 : tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui n01644900
# 1.84 : African chameleon, Chamaeleo chamaeleon n01694178
# 1.54 : beaver n02363005
# 1.49 : mongoose n02137549
# 1.47 : hare n02326432
# 1.34 : electric ray, crampfish, numbfish, torpedo n01496331
# 1.28 : titi, titi monkey n02493509
# ['n02356798', 'n02490219', 'n01688243', 'n01644900', 'n01694178', 'n02363005', 'n02137549', 'n02326432', 'n01496331', 'n02493509']
# 10.71 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 3.62 : marmoset n02490219
# 2.35 : frilled lizard, Chlamydosaurus kingi n01688243
# 2.02 : tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui n01644900
# 1.84 : African chameleon, Chamaeleo chamaeleon n01694178
# 1.54 : beaver n02363005
# 1.49 : mongoose n02137549
# 1.47 : hare n02326432
# 1.34 : electric ray, crampfish, numbfish, torpedo n01496331
# 1.28 : titi, titi monkey n02493509
# ../../data/92_image/animate/7.jpeg 2.95 : Windsor tie n04591157
# 1.87 : dumbbell n03255030
# 1.44 : horizontal bar, high bar n03535780
# 1.38 : punching bag, punch bag, punching ball, punchball n04023962
# 1.30 : jacamar n01843065
# 1.27 : hatchet n03498962
# 1.14 : overskirt n03866082
# 1.07 : torch n04456115
# 1.01 : hoopskirt, crinoline n03534580
# 0.86 : bulletproof vest n02916936
# ['n04591157', 'n03255030', 'n03535780', 'n04023962', 'n01843065', 'n03498962', 'n03866082', 'n04456115', 'n03534580', 'n02916936']
# 2.95 : Windsor tie n04591157
# 1.87 : dumbbell n03255030
# 1.44 : horizontal bar, high bar n03535780
# 1.38 : punching bag, punch bag, punching ball, punchball n04023962
# 1.30 : jacamar n01843065
# 1.27 : hatchet n03498962
# 1.14 : overskirt n03866082
# 1.07 : torch n04456115
# 1.01 : hoopskirt, crinoline n03534580
# 0.86 : bulletproof vest n02916936
# ../../data/92_image/animate/23.jpeg 8.19 : neck brace n03814639
# 4.95 : Band Aid n02786058
# 3.30 : face powder n03314780
# 3.15 : sunscreen, sunblock, sun blocker n04357314
# 2.66 : whistle n04579432
# 2.17 : nipple n03825788
# 2.01 : oboe, hautboy, hautbois n03838899
# 1.84 : lab coat, laboratory coat n03630383
# 1.71 : ice lolly, lolly, lollipop, popsicle n07615774
# 1.71 : lipstick, lip rouge n03676483
# ['n03814639', 'n02786058', 'n03314780', 'n04357314', 'n04579432', 'n03825788', 'n03838899', 'n03630383', 'n07615774', 'n03676483']
# 8.19 : neck brace n03814639
# 4.95 : Band Aid n02786058
# 3.30 : face powder n03314780
# 3.15 : sunscreen, sunblock, sun blocker n04357314
# 2.66 : whistle n04579432
# 2.17 : nipple n03825788
# 2.01 : oboe, hautboy, hautbois n03838899
# 1.84 : lab coat, laboratory coat n03630383
# 1.71 : ice lolly, lolly, lollipop, popsicle n07615774
# 1.71 : lipstick, lip rouge n03676483
# ../../data/92_image/animate/9.jpeg 3.69 : magnetic compass n03706229
# 2.37 : chambered nautilus, pearly nautilus, nautilus n01968897
# 1.94 : muzzle n03803284
# 1.70 : nipple n03825788
# 1.63 : whistle n04579432
# 1.62 : combination lock n03075370
# 1.39 : loupe, jeweler's loupe n03692522
# 1.23 : hair slide n03476684
# 1.22 : gong, tam-tam n03447721
# 1.10 : sunscreen, sunblock, sun blocker n04357314
# ['n03706229', 'n01968897', 'n03803284', 'n03825788', 'n04579432', 'n03075370', 'n03692522', 'n03476684', 'n03447721', 'n04357314']
# 3.69 : magnetic compass n03706229
# 2.37 : chambered nautilus, pearly nautilus, nautilus n01968897
# 1.94 : muzzle n03803284
# 1.70 : nipple n03825788
# 1.63 : whistle n04579432
# 1.62 : combination lock n03075370
# 1.39 : loupe, jeweler's loupe n03692522
# 1.23 : hair slide n03476684
# 1.22 : gong, tam-tam n03447721
# 1.10 : sunscreen, sunblock, sun blocker n04357314
# ../../data/92_image/animate/33.jpeg 22.74 : Indian elephant, Elephas maximus n02504013
# 14.58 : tusker n01871265
# 13.96 : African elephant, Loxodonta africana n02504458
# 4.04 : Arabian camel, dromedary, Camelus dromedarius n02437312
# 2.75 : ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus n02134084
# 2.41 : Irish wolfhound n02090721
# 1.94 : brown bear, bruin, Ursus arctos n02132136
# 1.66 : triceratops n01704323
# 1.58 : cougar, puma, catamount, mountain lion, painter, panther, Felis concolor n02125311
# 1.41 : Bedlington terrier n02093647
# ['n02504013', 'n01871265', 'n02504458', 'n02437312', 'n02134084', 'n02090721', 'n02132136', 'n01704323', 'n02125311', 'n02093647']
# 22.74 : Indian elephant, Elephas maximus n02504013
# 14.58 : tusker n01871265
# 13.96 : African elephant, Loxodonta africana n02504458
# 4.04 : Arabian camel, dromedary, Camelus dromedarius n02437312
# 2.75 : ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus n02134084
# 2.41 : Irish wolfhound n02090721
# 1.94 : brown bear, bruin, Ursus arctos n02132136
# 1.66 : triceratops n01704323
# 1.58 : cougar, puma, catamount, mountain lion, painter, panther, Felis concolor n02125311
# 1.41 : Bedlington terrier n02093647
# ../../data/92_image/animate/28.jpeg 3.93 : frilled lizard, Chlamydosaurus kingi n01688243
# 3.22 : triceratops n01704323
# 2.92 : African chameleon, Chamaeleo chamaeleon n01694178
# 2.56 : banded gecko n01675722
# 2.41 : kite n01608432
# 2.17 : common newt, Triturus vulgaris n01630670
# 2.02 : agama n01687978
# 1.92 : alligator lizard n01689811
# 1.78 : weevil n02177972
# 1.35 : whiptail, whiptail lizard n01685808
# ['n01688243', 'n01704323', 'n01694178', 'n01675722', 'n01608432', 'n01630670', 'n01687978', 'n01689811', 'n02177972', 'n01685808']
# 3.93 : frilled lizard, Chlamydosaurus kingi n01688243
# 3.22 : triceratops n01704323
# 2.92 : African chameleon, Chamaeleo chamaeleon n01694178
# 2.56 : banded gecko n01675722
# 2.41 : kite n01608432
# 2.17 : common newt, Triturus vulgaris n01630670
# 2.02 : agama n01687978
# 1.92 : alligator lizard n01689811
# 1.78 : weevil n02177972
# 1.35 : whiptail, whiptail lizard n01685808
# ../../data/92_image/animate/26.jpeg 85.13 : Arabian camel, dromedary, Camelus dromedarius n02437312
# 1.74 : bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis n02415577
# 0.73 : ibex, Capra ibex n02417914
# 0.44 : standard poodle n02113799
# 0.44 : earthstar n13044778
# 0.30 : hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa n13052670
# 0.28 : triceratops n01704323
# 0.26 : gyromitra n13037406
# 0.23 : llama n02437616
# 0.22 : Chesapeake Bay retriever n02099849
# ['n02437312', 'n02415577', 'n02417914', 'n02113799', 'n13044778', 'n13052670', 'n01704323', 'n13037406', 'n02437616', 'n02099849']
# 85.13 : Arabian camel, dromedary, Camelus dromedarius n02437312
# 1.74 : bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis n02415577
# 0.73 : ibex, Capra ibex n02417914
# 0.44 : standard poodle n02113799
# 0.44 : earthstar n13044778
# 0.30 : hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa n13052670
# 0.28 : triceratops n01704323
# 0.26 : gyromitra n13037406
# 0.23 : llama n02437616
# 0.22 : Chesapeake Bay retriever n02099849
# ../../data/92_image/animate/43.jpeg 8.15 : guenon, guenon monkey n02484975
# 6.08 : patas, hussar monkey, Erythrocebus patas n02486261
# 4.11 : baboon n02486410
# 2.74 : wool, woolen, woollen n04599235
# 2.68 : chambered nautilus, pearly nautilus, nautilus n01968897
# 2.39 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 2.33 : titi, titi monkey n02493509
# 2.20 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 1.86 : squirrel monkey, Saimiri sciureus n02494079
# 1.86 : mongoose n02137549
# ['n02484975', 'n02486261', 'n02486410', 'n04599235', 'n01968897', 'n01873310', 'n02493509', 'n02356798', 'n02494079', 'n02137549']
# 8.15 : guenon, guenon monkey n02484975
# 6.08 : patas, hussar monkey, Erythrocebus patas n02486261
# 4.11 : baboon n02486410
# 2.74 : wool, woolen, woollen n04599235
# 2.68 : chambered nautilus, pearly nautilus, nautilus n01968897
# 2.39 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 2.33 : titi, titi monkey n02493509
# 2.20 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 1.86 : squirrel monkey, Saimiri sciureus n02494079
# 1.86 : mongoose n02137549
# ../../data/92_image/animate/36.jpeg 9.08 : tick n01776313
# 5.77 : barn spider, Araneus cavaticus n01773549
# 5.45 : African chameleon, Chamaeleo chamaeleon n01694178
# 3.89 : king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica n01981276
# 3.54 : isopod n01990800
# 2.80 : tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui n01644900
# 2.70 : honeycomb n03530642
# 1.74 : hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa n13052670
# 1.52 : rock crab, Cancer irroratus n01978455
# 1.46 : earthstar n13044778
# ['n01776313', 'n01773549', 'n01694178', 'n01981276', 'n01990800', 'n01644900', 'n03530642', 'n13052670', 'n01978455', 'n13044778']
# 9.08 : tick n01776313
# 5.77 : barn spider, Araneus cavaticus n01773549
# 5.45 : African chameleon, Chamaeleo chamaeleon n01694178
# 3.89 : king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica n01981276
# 3.54 : isopod n01990800
# 2.80 : tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui n01644900
# 2.70 : honeycomb n03530642
# 1.74 : hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa n13052670
# 1.52 : rock crab, Cancer irroratus n01978455
# 1.46 : earthstar n13044778
# ../../data/92_image/animate/37.jpeg 18.04 : hartebeest n02422106
# 4.78 : ox n02403003
# 4.30 : ibex, Capra ibex n02417914
# 4.16 : gazelle n02423022
# 3.09 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 2.63 : Mexican hairless n02113978
# 2.57 : bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis n02415577
# 2.56 : impala, Aepyceros melampus n02422699
# 1.85 : English foxhound n02089973
# 1.56 : African hunting dog, hyena dog, Cape hunting dog, Lycaon pictus n02116738
# ['n02422106', 'n02403003', 'n02417914', 'n02423022', 'n01873310', 'n02113978', 'n02415577', 'n02422699', 'n02089973', 'n02116738']
# 18.04 : hartebeest n02422106
# 4.78 : ox n02403003
# 4.30 : ibex, Capra ibex n02417914
# 4.16 : gazelle n02423022
# 3.09 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 2.63 : Mexican hairless n02113978
# 2.57 : bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis n02415577
# 2.56 : impala, Aepyceros melampus n02422699
# 1.85 : English foxhound n02089973
# 1.56 : African hunting dog, hyena dog, Cape hunting dog, Lycaon pictus n02116738
# ../../data/92_image/animate/35.jpeg 7.17 : armadillo n02454379
# 4.01 : tusker n01871265
# 3.01 : African elephant, Loxodonta africana n02504458
# 2.88 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 2.24 : hog, pig, grunter, squealer, Sus scrofa n02395406
# 1.61 : bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis n02415577
# 1.56 : wild boar, boar, Sus scrofa n02396427
# 1.31 : dugong, Dugong dugon n02074367
# 1.29 : ibex, Capra ibex n02417914
# 1.22 : Indian elephant, Elephas maximus n02504013
# ['n02454379', 'n01871265', 'n02504458', 'n01873310', 'n02395406', 'n02415577', 'n02396427', 'n02074367', 'n02417914', 'n02504013']
# 7.17 : armadillo n02454379
# 4.01 : tusker n01871265
# 3.01 : African elephant, Loxodonta africana n02504458
# 2.88 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 2.24 : hog, pig, grunter, squealer, Sus scrofa n02395406
# 1.61 : bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis n02415577
# 1.56 : wild boar, boar, Sus scrofa n02396427
# 1.31 : dugong, Dugong dugon n02074367
# 1.29 : ibex, Capra ibex n02417914
# 1.22 : Indian elephant, Elephas maximus n02504013
# ../../data/92_image/animate/2.jpeg 3.94 : ocarina, sweet potato n03840681
# 2.03 : Band Aid n02786058
# 2.03 : loupe, jeweler's loupe n03692522
# 1.61 : ski mask n04229816
# 1.56 : knee pad n03623198
# 1.30 : mask n03724870
# 1.25 : switch, electric switch, electrical switch n04372370
# 1.15 : face powder n03314780
# 1.14 : black-footed ferret, ferret, Mustela nigripes n02443484
# 1.10 : pick, plectrum, plectron n03929660
# ['n03840681', 'n02786058', 'n03692522', 'n04229816', 'n03623198', 'n03724870', 'n04372370', 'n03314780', 'n02443484', 'n03929660']
# 3.94 : ocarina, sweet potato n03840681
# 2.03 : Band Aid n02786058
# 2.03 : loupe, jeweler's loupe n03692522
# 1.61 : ski mask n04229816
# 1.56 : knee pad n03623198
# 1.30 : mask n03724870
# 1.25 : switch, electric switch, electrical switch n04372370
# 1.15 : face powder n03314780
# 1.14 : black-footed ferret, ferret, Mustela nigripes n02443484
# 1.10 : pick, plectrum, plectron n03929660
# ../../data/92_image/animate/27.jpeg 8.32 : African chameleon, Chamaeleo chamaeleon n01694178
# 4.70 : banded gecko n01675722
# 4.53 : nematode, nematode worm, roundworm n01930112
# 4.37 : horned viper, cerastes, sand viper, horned asp, Cerastes cornutus n01753488
# 4.26 : green mamba n01749939
# 4.22 : sidewinder, horned rattlesnake, Crotalus cerastes n01756291
# 3.24 : vine snake n01739381
# 2.54 : chain n02999410
# 1.47 : rock python, rock snake, Python sebae n01744401
# 1.34 : night snake, Hypsiglena torquata n01740131
# ['n01694178', 'n01675722', 'n01930112', 'n01753488', 'n01749939', 'n01756291', 'n01739381', 'n02999410', 'n01744401', 'n01740131']
# 8.32 : African chameleon, Chamaeleo chamaeleon n01694178
# 4.70 : banded gecko n01675722
# 4.53 : nematode, nematode worm, roundworm n01930112
# 4.37 : horned viper, cerastes, sand viper, horned asp, Cerastes cornutus n01753488
# 4.26 : green mamba n01749939
# 4.22 : sidewinder, horned rattlesnake, Crotalus cerastes n01756291
# 3.24 : vine snake n01739381
# 2.54 : chain n02999410
# 1.47 : rock python, rock snake, Python sebae n01744401
# 1.34 : night snake, Hypsiglena torquata n01740131
# ../../data/92_image/animate/30.jpeg 16.13 : kite n01608432
# 13.15 : dowitcher n02033041
# 7.03 : black stork, Ciconia nigra n02002724
# 4.39 : limpkin, Aramus pictus n02013706
# 3.00 : redshank, Tringa totanus n02028035
# 2.67 : ruddy turnstone, Arenaria interpres n02025239
# 2.65 : African chameleon, Chamaeleo chamaeleon n01694178
# 2.46 : jacamar n01843065
# 2.21 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 1.82 : bittern n02011460
# ['n01608432', 'n02033041', 'n02002724', 'n02013706', 'n02028035', 'n02025239', 'n01694178', 'n01843065', 'n01873310', 'n02011460']
# 16.13 : kite n01608432
# 13.15 : dowitcher n02033041
# 7.03 : black stork, Ciconia nigra n02002724
# 4.39 : limpkin, Aramus pictus n02013706
# 3.00 : redshank, Tringa totanus n02028035
# 2.67 : ruddy turnstone, Arenaria interpres n02025239
# 2.65 : African chameleon, Chamaeleo chamaeleon n01694178
# 2.46 : jacamar n01843065
# 2.21 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 1.82 : bittern n02011460
# ../../data/92_image/animate/10.jpeg 3.34 : sweatshirt n04370456
# 2.83 : Windsor tie n04591157
# 2.76 : overskirt n03866082
# 2.49 : trench coat n04479046
# 2.19 : suit, suit of clothes n04350905
# 2.09 : pajama, pyjama, pj's, jammies n03877472
# 1.94 : velvet n04525038
# 1.89 : jersey, T-shirt, tee shirt n03595614
# 1.76 : cloak n03045698
# 1.66 : stole n04325704
# ['n04370456', 'n04591157', 'n03866082', 'n04479046', 'n04350905', 'n03877472', 'n04525038', 'n03595614', 'n03045698', 'n04325704']
# 3.34 : sweatshirt n04370456
# 2.83 : Windsor tie n04591157
# 2.76 : overskirt n03866082
# 2.49 : trench coat n04479046
# 2.19 : suit, suit of clothes n04350905
# 2.09 : pajama, pyjama, pj's, jammies n03877472
# 1.94 : velvet n04525038
# 1.89 : jersey, T-shirt, tee shirt n03595614
# 1.76 : cloak n03045698
# 1.66 : stole n04325704
# ../../data/92_image/animate/41.jpeg 24.65 : German shepherd, German shepherd dog, German police dog, alsatian n02106662
# 11.14 : kelpie n02105412
# 5.50 : malinois n02105162
# 4.64 : muzzle n03803284
# 4.46 : dingo, warrigal, warragal, Canis dingo n02115641
# 4.32 : Cardigan, Cardigan Welsh corgi n02113186
# 2.38 : toy terrier n02087046
# 2.35 : Australian terrier n02096294
# 2.28 : Norwegian elkhound, elkhound n02091467
# 1.88 : Pembroke, Pembroke Welsh corgi n02113023
# ['n02106662', 'n02105412', 'n02105162', 'n03803284', 'n02115641', 'n02113186', 'n02087046', 'n02096294', 'n02091467', 'n02113023']
# 24.65 : German shepherd, German shepherd dog, German police dog, alsatian n02106662
# 11.14 : kelpie n02105412
# 5.50 : malinois n02105162
# 4.64 : muzzle n03803284
# 4.46 : dingo, warrigal, warragal, Canis dingo n02115641
# 4.32 : Cardigan, Cardigan Welsh corgi n02113186
# 2.38 : toy terrier n02087046
# 2.35 : Australian terrier n02096294
# 2.28 : Norwegian elkhound, elkhound n02091467
# 1.88 : Pembroke, Pembroke Welsh corgi n02113023
# ../../data/92_image/animate/25.jpeg 80.38 : armadillo n02454379
# 2.38 : isopod n01990800
# 2.10 : triceratops n01704323
# 1.54 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 0.86 : mongoose n02137549
# 0.74 : terrapin n01667778
# 0.69 : prairie chicken, prairie grouse, prairie fowl n01798484
# 0.46 : weevil n02177972
# 0.40 : kite n01608432
# 0.37 : banded gecko n01675722
# ['n02454379', 'n01990800', 'n01704323', 'n01873310', 'n02137549', 'n01667778', 'n01798484', 'n02177972', 'n01608432', 'n01675722']
# 80.38 : armadillo n02454379
# 2.38 : isopod n01990800
# 2.10 : triceratops n01704323
# 1.54 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 0.86 : mongoose n02137549
# 0.74 : terrapin n01667778
# 0.69 : prairie chicken, prairie grouse, prairie fowl n01798484
# 0.46 : weevil n02177972
# 0.40 : kite n01608432
# 0.37 : banded gecko n01675722
# ../../data/92_image/animate/42.jpeg 24.42 : Great Dane n02109047
# 10.13 : Doberman, Doberman pinscher n02107142
# 7.89 : Mexican hairless n02113978
# 6.01 : Ibizan hound, Ibizan Podenco n02091244
# 4.86 : malinois n02105162
# 3.25 : basenji n02110806
# 3.18 : toy terrier n02087046
# 2.86 : muzzle n03803284
# 2.42 : Rhodesian ridgeback n02087394
# 2.17 : redbone n02090379
# ['n02109047', 'n02107142', 'n02113978', 'n02091244', 'n02105162', 'n02110806', 'n02087046', 'n03803284', 'n02087394', 'n02090379']
# 24.42 : Great Dane n02109047
# 10.13 : Doberman, Doberman pinscher n02107142
# 7.89 : Mexican hairless n02113978
# 6.01 : Ibizan hound, Ibizan Podenco n02091244
# 4.86 : malinois n02105162
# 3.25 : basenji n02110806
# 3.18 : toy terrier n02087046
# 2.86 : muzzle n03803284
# 2.42 : Rhodesian ridgeback n02087394
# 2.17 : redbone n02090379
# ../../data/92_image/animate/15.jpeg 4.01 : Band Aid n02786058
# 3.96 : lipstick, lip rouge n03676483
# 3.48 : whistle n04579432
# 2.59 : sunscreen, sunblock, sun blocker n04357314
# 2.30 : face powder n03314780
# 1.88 : Windsor tie n04591157
# 1.52 : swimming trunks, bathing trunks n04371430
# 1.51 : knee pad n03623198
# 1.42 : sweatshirt n04370456
# 1.36 : harmonica, mouth organ, harp, mouth harp n03494278
# ['n02786058', 'n03676483', 'n04579432', 'n04357314', 'n03314780', 'n04591157', 'n04371430', 'n03623198', 'n04370456', 'n03494278']
# 4.01 : Band Aid n02786058
# 3.96 : lipstick, lip rouge n03676483
# 3.48 : whistle n04579432
# 2.59 : sunscreen, sunblock, sun blocker n04357314
# 2.30 : face powder n03314780
# 1.88 : Windsor tie n04591157
# 1.52 : swimming trunks, bathing trunks n04371430
# 1.51 : knee pad n03623198
# 1.42 : sweatshirt n04370456
# 1.36 : harmonica, mouth organ, harp, mouth harp n03494278
# ../../data/92_image/animate/32.jpeg 67.37 : zebra n02391049
# 2.71 : tiger, Panthera tigris n02129604
# 2.00 : prairie chicken, prairie grouse, prairie fowl n01798484
# 1.65 : flatworm, platyhelminth n01924916
# 1.34 : chambered nautilus, pearly nautilus, nautilus n01968897
# 0.95 : coil, spiral, volute, whorl, helix n03065424
# 0.90 : tiger cat n02123159
# 0.71 : lionfish n02643566
# 0.69 : screw n04153751
# 0.56 : echidna, spiny anteater, anteater n01872401
# ['n02391049', 'n02129604', 'n01798484', 'n01924916', 'n01968897', 'n03065424', 'n02123159', 'n02643566', 'n04153751', 'n01872401']
# 67.37 : zebra n02391049
# 2.71 : tiger, Panthera tigris n02129604
# 2.00 : prairie chicken, prairie grouse, prairie fowl n01798484
# 1.65 : flatworm, platyhelminth n01924916
# 1.34 : chambered nautilus, pearly nautilus, nautilus n01968897
# 0.95 : coil, spiral, volute, whorl, helix n03065424
# 0.90 : tiger cat n02123159
# 0.71 : lionfish n02643566
# 0.69 : screw n04153751
# 0.56 : echidna, spiny anteater, anteater n01872401
# ../../data/92_image/animate/1.jpeg 4.74 : Band Aid n02786058
# 3.33 : spatula n04270147
# 3.13 : panpipe, pandean pipe, syrinx n03884397
# 2.62 : swimming trunks, bathing trunks n04371430
# 1.90 : knee pad n03623198
# 1.90 : Windsor tie n04591157
# 1.67 : conch n01943899
# 1.60 : paintbrush n03876231
# 1.43 : ballpoint, ballpoint pen, ballpen, Biro n02783161
# 1.22 : matchstick n03729826
# ['n02786058', 'n04270147', 'n03884397', 'n04371430', 'n03623198', 'n04591157', 'n01943899', 'n03876231', 'n02783161', 'n03729826']
# 4.74 : Band Aid n02786058
# 3.33 : spatula n04270147
# 3.13 : panpipe, pandean pipe, syrinx n03884397
# 2.62 : swimming trunks, bathing trunks n04371430
# 1.90 : knee pad n03623198
# 1.90 : Windsor tie n04591157
# 1.67 : conch n01943899
# 1.60 : paintbrush n03876231
# 1.43 : ballpoint, ballpoint pen, ballpen, Biro n02783161
# 1.22 : matchstick n03729826
# ../../data/92_image/animate/47.jpeg 42.62 : lion, king of beasts, Panthera leo n02129165
# 4.50 : cheetah, chetah, Acinonyx jubatus n02130308
# 4.44 : coyote, prairie wolf, brush wolf, Canis latrans n02114855
# 3.56 : red wolf, maned wolf, Canis rufus, Canis niger n02114712
# 3.47 : dingo, warrigal, warragal, Canis dingo n02115641
# 2.73 : lynx, catamount n02127052
# 2.39 : timber wolf, grey wolf, gray wolf, Canis lupus n02114367
# 2.23 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 1.98 : Egyptian cat n02124075
# 1.81 : cougar, puma, catamount, mountain lion, painter, panther, Felis concolor n02125311
# ['n02129165', 'n02130308', 'n02114855', 'n02114712', 'n02115641', 'n02127052', 'n02114367', 'n02356798', 'n02124075', 'n02125311']
# 42.62 : lion, king of beasts, Panthera leo n02129165
# 4.50 : cheetah, chetah, Acinonyx jubatus n02130308
# 4.44 : coyote, prairie wolf, brush wolf, Canis latrans n02114855
# 3.56 : red wolf, maned wolf, Canis rufus, Canis niger n02114712
# 3.47 : dingo, warrigal, warragal, Canis dingo n02115641
# 2.73 : lynx, catamount n02127052
# 2.39 : timber wolf, grey wolf, gray wolf, Canis lupus n02114367
# 2.23 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 1.98 : Egyptian cat n02124075
# 1.81 : cougar, puma, catamount, mountain lion, painter, panther, Felis concolor n02125311
# ../../data/92_image/animate/13.jpeg 5.47 : oxygen mask n03868863
# 5.47 : sunscreen, sunblock, sun blocker n04357314
# 4.80 : neck brace n03814639
# 4.49 : whistle n04579432
# 3.49 : Band Aid n02786058
# 2.63 : loupe, jeweler's loupe n03692522
# 2.40 : Windsor tie n04591157
# 2.24 : mask n03724870
# 2.24 : gasmask, respirator, gas helmet n03424325
# 2.16 : oboe, hautboy, hautbois n03838899
# ['n03868863', 'n04357314', 'n03814639', 'n04579432', 'n02786058', 'n03692522', 'n04591157', 'n03724870', 'n03424325', 'n03838899']
# 5.47 : oxygen mask n03868863
# 5.47 : sunscreen, sunblock, sun blocker n04357314
# 4.80 : neck brace n03814639
# 4.49 : whistle n04579432
# 3.49 : Band Aid n02786058
# 2.63 : loupe, jeweler's loupe n03692522
# 2.40 : Windsor tie n04591157
# 2.24 : mask n03724870
# 2.24 : gasmask, respirator, gas helmet n03424325
# 2.16 : oboe, hautboy, hautbois n03838899
# ../../data/92_image/animate/14.jpeg 38.56 : sunglass n04355933
# 22.52 : bathing cap, swimming cap n02807133
# 4.99 : loupe, jeweler's loupe n03692522
# 4.99 : ski mask n04229816
# 4.33 : sunglasses, dark glasses, shades n04356056
# 2.75 : mask n03724870
# 2.38 : oxygen mask n03868863
# 1.79 : Band Aid n02786058
# 1.66 : neck brace n03814639
# 1.44 : snorkel n04251144
# ['n04355933', 'n02807133', 'n03692522', 'n04229816', 'n04356056', 'n03724870', 'n03868863', 'n02786058', 'n03814639', 'n04251144']
# 38.56 : sunglass n04355933
# 22.52 : bathing cap, swimming cap n02807133
# 4.99 : loupe, jeweler's loupe n03692522
# 4.99 : ski mask n04229816
# 4.33 : sunglasses, dark glasses, shades n04356056
# 2.75 : mask n03724870
# 2.38 : oxygen mask n03868863
# 1.79 : Band Aid n02786058
# 1.66 : neck brace n03814639
# 1.44 : snorkel n04251144
# ../../data/92_image/animate/40.jpeg 9.81 : proboscis monkey, Nasalis larvatus n02489166
# 5.33 : patas, hussar monkey, Erythrocebus patas n02486261
# 2.17 : chimpanzee, chimp, Pan troglodytes n02481823
# 1.95 : sea lion n02077923
# 1.75 : partridge n01807496
# 1.74 : macaque n02487347
# 1.71 : ocarina, sweet potato n03840681
# 1.37 : titi, titi monkey n02493509
# 1.11 : guenon, guenon monkey n02484975
# 1.10 : howler monkey, howler n02492660
# ['n02489166', 'n02486261', 'n02481823', 'n02077923', 'n01807496', 'n02487347', 'n03840681', 'n02493509', 'n02484975', 'n02492660']
# 9.81 : proboscis monkey, Nasalis larvatus n02489166
# 5.33 : patas, hussar monkey, Erythrocebus patas n02486261
# 2.17 : chimpanzee, chimp, Pan troglodytes n02481823
# 1.95 : sea lion n02077923
# 1.75 : partridge n01807496
# 1.74 : macaque n02487347
# 1.71 : ocarina, sweet potato n03840681
# 1.37 : titi, titi monkey n02493509
# 1.11 : guenon, guenon monkey n02484975
# 1.10 : howler monkey, howler n02492660
# ../../data/92_image/animate/39.jpeg 5.07 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 3.21 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 2.83 : marmoset n02490219
# 2.11 : ocarina, sweet potato n03840681
# 1.79 : polecat, fitch, foulmart, foumart, Mustela putorius n02443114
# 1.76 : weasel n02441942
# 1.70 : wombat n01883070
# 1.49 : pickelhaube n03929855
# 1.42 : piggy bank, penny bank n03935335
# 1.28 : mink n02442845
# ['n02356798', 'n01873310', 'n02490219', 'n03840681', 'n02443114', 'n02441942', 'n01883070', 'n03929855', 'n03935335', 'n02442845']
# 5.07 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 3.21 : platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus n01873310
# 2.83 : marmoset n02490219
# 2.11 : ocarina, sweet potato n03840681
# 1.79 : polecat, fitch, foulmart, foumart, Mustela putorius n02443114
# 1.76 : weasel n02441942
# 1.70 : wombat n01883070
# 1.49 : pickelhaube n03929855
# 1.42 : piggy bank, penny bank n03935335
# 1.28 : mink n02442845
# ../../data/92_image/animate/46.jpeg 7.70 : hartebeest n02422106
# 5.13 : hare n02326432
# 3.93 : wallaby, brush kangaroo n01877812
# 3.20 : ibex, Capra ibex n02417914
# 2.90 : grey fox, gray fox, Urocyon cinereoargenteus n02120505
# 2.78 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 2.59 : gazelle n02423022
# 2.52 : Egyptian cat n02124075
# 2.01 : lynx, catamount n02127052
# 1.91 : kit fox, Vulpes macrotis n02119789
# ['n02422106', 'n02326432', 'n01877812', 'n02417914', 'n02120505', 'n02356798', 'n02423022', 'n02124075', 'n02127052', 'n02119789']
# 7.70 : hartebeest n02422106
# 5.13 : hare n02326432
# 3.93 : wallaby, brush kangaroo n01877812
# 3.20 : ibex, Capra ibex n02417914
# 2.90 : grey fox, gray fox, Urocyon cinereoargenteus n02120505
# 2.78 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 2.59 : gazelle n02423022
# 2.52 : Egyptian cat n02124075
# 2.01 : lynx, catamount n02127052
# 1.91 : kit fox, Vulpes macrotis n02119789
# ../../data/92_image/animate/19.jpeg 13.94 : mask n03724870
# 10.00 : ski mask n04229816
# 6.13 : shower cap n04209133
# 5.55 : neck brace n03814639
# 4.80 : sunscreen, sunblock, sun blocker n04357314
# 3.58 : Band Aid n02786058
# 2.80 : wool, woolen, woollen n04599235
# 2.28 : bonnet, poke bonnet n02869837
# 1.87 : sweatshirt n04370456
# 1.79 : Windsor tie n04591157
# ['n03724870', 'n04229816', 'n04209133', 'n03814639', 'n04357314', 'n02786058', 'n04599235', 'n02869837', 'n04370456', 'n04591157']
# 13.94 : mask n03724870
# 10.00 : ski mask n04229816
# 6.13 : shower cap n04209133
# 5.55 : neck brace n03814639
# 4.80 : sunscreen, sunblock, sun blocker n04357314
# 3.58 : Band Aid n02786058
# 2.80 : wool, woolen, woollen n04599235
# 2.28 : bonnet, poke bonnet n02869837
# 1.87 : sweatshirt n04370456
# 1.79 : Windsor tie n04591157
# ../../data/92_image/animate/48.jpeg 5.56 : wig n04584207
# 5.12 : loupe, jeweler's loupe n03692522
# 2.96 : sunscreen, sunblock, sun blocker n04357314
# 2.63 : patas, hussar monkey, Erythrocebus patas n02486261
# 2.14 : squirrel monkey, Saimiri sciureus n02494079
# 1.99 : macaque n02487347
# 1.75 : titi, titi monkey n02493509
# 1.65 : mask n03724870
# 1.65 : shower cap n04209133
# 1.59 : guenon, guenon monkey n02484975
# ['n04584207', 'n03692522', 'n04357314', 'n02486261', 'n02494079', 'n02487347', 'n02493509', 'n03724870', 'n04209133', 'n02484975']
# 5.56 : wig n04584207
# 5.12 : loupe, jeweler's loupe n03692522
# 2.96 : sunscreen, sunblock, sun blocker n04357314
# 2.63 : patas, hussar monkey, Erythrocebus patas n02486261
# 2.14 : squirrel monkey, Saimiri sciureus n02494079
# 1.99 : macaque n02487347
# 1.75 : titi, titi monkey n02493509
# 1.65 : mask n03724870
# 1.65 : shower cap n04209133
# 1.59 : guenon, guenon monkey n02484975
# ../../data/92_image/animate/24.jpeg 6.40 : neck brace n03814639
# 4.84 : Band Aid n02786058
# 4.32 : Windsor tie n04591157
# 2.90 : bearskin, busby, shako n02817516
# 2.22 : bow tie, bow-tie, bowtie n02883205
# 2.02 : loupe, jeweler's loupe n03692522
# 1.99 : academic gown, academic robe, judge's robe n02669723
# 1.96 : ski mask n04229816
# 1.91 : pick, plectrum, plectron n03929660
# 1.86 : panpipe, pandean pipe, syrinx n03884397
# ['n03814639', 'n02786058', 'n04591157', 'n02817516', 'n02883205', 'n03692522', 'n02669723', 'n04229816', 'n03929660', 'n03884397']
# 6.40 : neck brace n03814639
# 4.84 : Band Aid n02786058
# 4.32 : Windsor tie n04591157
# 2.90 : bearskin, busby, shako n02817516
# 2.22 : bow tie, bow-tie, bowtie n02883205
# 2.02 : loupe, jeweler's loupe n03692522
# 1.99 : academic gown, academic robe, judge's robe n02669723
# 1.96 : ski mask n04229816
# 1.91 : pick, plectrum, plectron n03929660
# 1.86 : panpipe, pandean pipe, syrinx n03884397
# ../../data/92_image/animate/6.jpeg 6.29 : hoopskirt, crinoline n03534580
# 3.41 : overskirt n03866082
# 2.37 : dumbbell n03255030
# 2.27 : maillot n03710637
# 2.15 : maillot, tank suit n03710721
# 1.98 : balance beam, beam n02777292
# 1.77 : horizontal bar, high bar n03535780
# 1.67 : barbell n02790996
# 1.53 : sarong n04136333
# 1.50 : swimming trunks, bathing trunks n04371430
# ['n03534580', 'n03866082', 'n03255030', 'n03710637', 'n03710721', 'n02777292', 'n03535780', 'n02790996', 'n04136333', 'n04371430']
# 6.29 : hoopskirt, crinoline n03534580
# 3.41 : overskirt n03866082
# 2.37 : dumbbell n03255030
# 2.27 : maillot n03710637
# 2.15 : maillot, tank suit n03710721
# 1.98 : balance beam, beam n02777292
# 1.77 : horizontal bar, high bar n03535780
# 1.67 : barbell n02790996
# 1.53 : sarong n04136333
# 1.50 : swimming trunks, bathing trunks n04371430
# ../../data/92_image/animate/8.jpeg 4.78 : Band Aid n02786058
# 3.42 : butternut squash n07717556
# 3.13 : plane, carpenter's plane, woodworking plane n03954731
# 2.89 : French loaf n07684084
# 2.34 : nematode, nematode worm, roundworm n01930112
# 2.10 : space shuttle n04266014
# 1.99 : ocarina, sweet potato n03840681
# 1.51 : dugong, Dugong dugon n02074367
# 1.36 : hog, pig, grunter, squealer, Sus scrofa n02395406
# 1.29 : nipple n03825788
# ['n02786058', 'n07717556', 'n03954731', 'n07684084', 'n01930112', 'n04266014', 'n03840681', 'n02074367', 'n02395406', 'n03825788']
# 4.78 : Band Aid n02786058
# 3.42 : butternut squash n07717556
# 3.13 : plane, carpenter's plane, woodworking plane n03954731
# 2.89 : French loaf n07684084
# 2.34 : nematode, nematode worm, roundworm n01930112
# 2.10 : space shuttle n04266014
# 1.99 : ocarina, sweet potato n03840681
# 1.51 : dugong, Dugong dugon n02074367
# 1.36 : hog, pig, grunter, squealer, Sus scrofa n02395406
# 1.29 : nipple n03825788
# ../../data/92_image/animate/44.jpeg 33.05 : macaque n02487347
# 14.14 : patas, hussar monkey, Erythrocebus patas n02486261
# 9.98 : titi, titi monkey n02493509
# 7.77 : proboscis monkey, Nasalis larvatus n02489166
# 6.69 : gibbon, Hylobates lar n02483362
# 3.40 : guenon, guenon monkey n02484975
# 3.07 : langur n02488291
# 2.63 : indri, indris, Indri indri, Indri brevicaudatus n02500267
# 2.51 : spider monkey, Ateles geoffroyi n02493793
# 2.43 : marmoset n02490219
# ['n02487347', 'n02486261', 'n02493509', 'n02489166', 'n02483362', 'n02484975', 'n02488291', 'n02500267', 'n02493793', 'n02490219']
# 33.05 : macaque n02487347
# 14.14 : patas, hussar monkey, Erythrocebus patas n02486261
# 9.98 : titi, titi monkey n02493509
# 7.77 : proboscis monkey, Nasalis larvatus n02489166
# 6.69 : gibbon, Hylobates lar n02483362
# 3.40 : guenon, guenon monkey n02484975
# 3.07 : langur n02488291
# 2.63 : indri, indris, Indri indri, Indri brevicaudatus n02500267
# 2.51 : spider monkey, Ateles geoffroyi n02493793
# 2.43 : marmoset n02490219
# ../../data/92_image/animate/22.jpeg 8.24 : neck brace n03814639
# 5.88 : oxygen mask n03868863
# 5.51 : Windsor tie n04591157
# 5.42 : whistle n04579432
# 5.33 : oboe, hautboy, hautbois n03838899
# 3.15 : Band Aid n02786058
# 2.95 : face powder n03314780
# 2.62 : academic gown, academic robe, judge's robe n02669723
# 2.51 : ocarina, sweet potato n03840681
# 2.09 : lab coat, laboratory coat n03630383
# ['n03814639', 'n03868863', 'n04591157', 'n04579432', 'n03838899', 'n02786058', 'n03314780', 'n02669723', 'n03840681', 'n03630383']
# 8.24 : neck brace n03814639
# 5.88 : oxygen mask n03868863
# 5.51 : Windsor tie n04591157
# 5.42 : whistle n04579432
# 5.33 : oboe, hautboy, hautbois n03838899
# 3.15 : Band Aid n02786058
# 2.95 : face powder n03314780
# 2.62 : academic gown, academic robe, judge's robe n02669723
# 2.51 : ocarina, sweet potato n03840681
# 2.09 : lab coat, laboratory coat n03630383
# ../../data/92_image/animate/29.jpeg 5.87 : patas, hussar monkey, Erythrocebus patas n02486261
# 5.45 : macaque n02487347
# 3.54 : baboon n02486410
# 3.37 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 1.97 : otterhound, otter hound n02091635
# 1.86 : titi, titi monkey n02493509
# 1.81 : squirrel monkey, Saimiri sciureus n02494079
# 1.58 : lion, king of beasts, Panthera leo n02129165
# 1.48 : brown bear, bruin, Ursus arctos n02132136
# 1.13 : komondor n02105505
# ['n02486261', 'n02487347', 'n02486410', 'n02356798', 'n02091635', 'n02493509', 'n02494079', 'n02129165', 'n02132136', 'n02105505']
# 5.87 : patas, hussar monkey, Erythrocebus patas n02486261
# 5.45 : macaque n02487347
# 3.54 : baboon n02486410
# 3.37 : fox squirrel, eastern fox squirrel, Sciurus niger n02356798
# 1.97 : otterhound, otter hound n02091635
# 1.86 : titi, titi monkey n02493509
# 1.81 : squirrel monkey, Saimiri sciureus n02494079
# 1.58 : lion, king of beasts, Panthera leo n02129165
# 1.48 : brown bear, bruin, Ursus arctos n02132136
# 1.13 : komondor n02105505
# ../../data/92_image/animate/21.jpeg 28.92 : wig n04584207
# 13.74 : shower cap n04209133
# 5.38 : Band Aid n02786058
# 3.87 : bonnet, poke bonnet n02869837
# 2.48 : sunscreen, sunblock, sun blocker n04357314
# 1.91 : nipple n03825788
# 1.60 : neck brace n03814639
# 1.42 : wool, woolen, woollen n04599235
# 1.38 : ice lolly, lolly, lollipop, popsicle n07615774
# 1.29 : mask n03724870
# ['n04584207', 'n04209133', 'n02786058', 'n02869837', 'n04357314', 'n03825788', 'n03814639', 'n04599235', 'n07615774', 'n03724870']
# 28.92 : wig n04584207
# 13.74 : shower cap n04209133
# 5.38 : Band Aid n02786058
# 3.87 : bonnet, poke bonnet n02869837
# 2.48 : sunscreen, sunblock, sun blocker n04357314
# 1.91 : nipple n03825788
# 1.60 : neck brace n03814639
# 1.42 : wool, woolen, woollen n04599235
# 1.38 : ice lolly, lolly, lollipop, popsicle n07615774
# 1.29 : mask n03724870
# ../../data/92_image/animate/31.jpeg 22.10 : king snake, kingsnake n01734418
# 5.87 : chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour n03000247
# 4.04 : screw n04153751
# 3.26 : chain n02999410
# 3.19 : coil, spiral, volute, whorl, helix n03065424
# 2.41 : night snake, Hypsiglena torquata n01740131
# 2.09 : necklace n03814906
# 1.81 : sea snake n01751748
# 1.75 : corkscrew, bottle screw n03109150
# 1.61 : safety pin n04127249
# ['n01734418', 'n03000247', 'n04153751', 'n02999410', 'n03065424', 'n01740131', 'n03814906', 'n01751748', 'n03109150', 'n04127249']
# 22.10 : king snake, kingsnake n01734418
# 5.87 : chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour n03000247
# 4.04 : screw n04153751
# 3.26 : chain n02999410
# 3.19 : coil, spiral, volute, whorl, helix n03065424
# 2.41 : night snake, Hypsiglena torquata n01740131
# 2.09 : necklace n03814906
# 1.81 : sea snake n01751748
# 1.75 : corkscrew, bottle screw n03109150
# 1.61 : safety pin n04127249
# ../../data/92_image/animate/11.jpeg 3.37 : Petri dish n03920288
# 2.04 : ocarina, sweet potato n03840681
# 2.00 : pick, plectrum, plectron n03929660
# 1.78 : thunder snake, worm snake, Carphophis amoenus n01728572
# 1.56 : piggy bank, penny bank n03935335
# 1.46 : chambered nautilus, pearly nautilus, nautilus n01968897
# 1.45 : sunscreen, sunblock, sun blocker n04357314
# 1.39 : Band Aid n02786058
# 1.32 : face powder n03314780
# 1.30 : mouse, computer mouse n03793489
# ['n03920288', 'n03840681', 'n03929660', 'n01728572', 'n03935335', 'n01968897', 'n04357314', 'n02786058', 'n03314780', 'n03793489']
# 3.37 : Petri dish n03920288
# 2.04 : ocarina, sweet potato n03840681
# 2.00 : pick, plectrum, plectron n03929660
# 1.78 : thunder snake, worm snake, Carphophis amoenus n01728572
# 1.56 : piggy bank, penny bank n03935335
# 1.46 : chambered nautilus, pearly nautilus, nautilus n01968897
# 1.45 : sunscreen, sunblock, sun blocker n04357314
# 1.39 : Band Aid n02786058
# 1.32 : face powder n03314780
# 1.30 : mouse, computer mouse n03793489
# ../../data/92_image/animate/17.jpeg 10.51 : Band Aid n02786058
# 9.52 : neck brace n03814639
# 6.52 : face powder n03314780
# 4.65 : sunscreen, sunblock, sun blocker n04357314
# 3.30 : oxygen mask n03868863
# 3.20 : loupe, jeweler's loupe n03692522
# 2.20 : nipple n03825788
# 2.17 : wig n04584207
# 1.35 : oboe, hautboy, hautbois n03838899
# 1.32 : panpipe, pandean pipe, syrinx n03884397
# ['n02786058', 'n03814639', 'n03314780', 'n04357314', 'n03868863', 'n03692522', 'n03825788', 'n04584207', 'n03838899', 'n03884397']
# 10.51 : Band Aid n02786058
# 9.52 : neck brace n03814639
# 6.52 : face powder n03314780
# 4.65 : sunscreen, sunblock, sun blocker n04357314
# 3.30 : oxygen mask n03868863
# 3.20 : loupe, jeweler's loupe n03692522
# 2.20 : nipple n03825788
# 2.17 : wig n04584207
# 1.35 : oboe, hautboy, hautbois n03838899
# 1.32 : panpipe, pandean pipe, syrinx n03884397
# ../../data/92_image/animate/4.jpeg 16.13 : lab coat, laboratory coat n03630383
# 2.25 : jersey, T-shirt, tee shirt n03595614
# 1.54 : knee pad n03623198
# 1.49 : Windsor tie n04591157
# 1.44 : sweatshirt n04370456
# 1.30 : suit, suit of clothes n04350905
# 1.23 : torch n04456115
# 1.21 : plastic bag n03958227
# 1.15 : bulletproof vest n02916936
# 1.13 : vestment n04532106
# ['n03630383', 'n03595614', 'n03623198', 'n04591157', 'n04370456', 'n04350905', 'n04456115', 'n03958227', 'n02916936', 'n04532106']
# 16.13 : lab coat, laboratory coat n03630383
# 2.25 : jersey, T-shirt, tee shirt n03595614
# 1.54 : knee pad n03623198
# 1.49 : Windsor tie n04591157
# 1.44 : sweatshirt n04370456
# 1.30 : suit, suit of clothes n04350905
# 1.23 : torch n04456115
# 1.21 : plastic bag n03958227
# 1.15 : bulletproof vest n02916936
# 1.13 : vestment n04532106
# ../../data/92_image/animate/45.jpeg 8.26 : American alligator, Alligator mississipiensis n01698640
# 3.68 : vine snake n01739381
# 3.16 : African crocodile, Nile crocodile, Crocodylus niloticus n01697457
# 2.60 : rock python, rock snake, Python sebae n01744401
# 2.57 : nematode, nematode worm, roundworm n01930112
# 2.50 : night snake, Hypsiglena torquata n01740131
# 2.33 : frilled lizard, Chlamydosaurus kingi n01688243
# 2.21 : leatherback turtle, leatherback, leathery turtle, Dermochelys coriacea n01665541
# 1.98 : sidewinder, horned rattlesnake, Crotalus cerastes n01756291
# 1.98 : whiptail, whiptail lizard n01685808
# ['n01698640', 'n01739381', 'n01697457', 'n01744401', 'n01930112', 'n01740131', 'n01688243', 'n01665541', 'n01756291', 'n01685808']
# 8.26 : American alligator, Alligator mississipiensis n01698640
# 3.68 : vine snake n01739381
# 3.16 : African crocodile, Nile crocodile, Crocodylus niloticus n01697457
# 2.60 : rock python, rock snake, Python sebae n01744401
# 2.57 : nematode, nematode worm, roundworm n01930112
# 2.50 : night snake, Hypsiglena torquata n01740131
# 2.33 : frilled lizard, Chlamydosaurus kingi n01688243
# 2.21 : leatherback turtle, leatherback, leathery turtle, Dermochelys coriacea n01665541
# 1.98 : sidewinder, horned rattlesnake, Crotalus cerastes n01756291
# 1.98 : whiptail, whiptail lizard n01685808
# ../../data/92_image/animate/18.jpeg 7.22 : neck brace n03814639
# 5.69 : sunscreen, sunblock, sun blocker n04357314
# 5.12 : Windsor tie n04591157
# 4.78 : Band Aid n02786058
# 3.41 : face powder n03314780
# 3.15 : oboe, hautboy, hautbois n03838899
# 2.80 : lab coat, laboratory coat n03630383
# 2.62 : suit, suit of clothes n04350905
# 1.85 : lipstick, lip rouge n03676483
# 1.73 : loupe, jeweler's loupe n03692522
# ['n03814639', 'n04357314', 'n04591157', 'n02786058', 'n03314780', 'n03838899', 'n03630383', 'n04350905', 'n03676483', 'n03692522']
# 7.22 : neck brace n03814639
# 5.69 : sunscreen, sunblock, sun blocker n04357314
# 5.12 : Windsor tie n04591157
# 4.78 : Band Aid n02786058
# 3.41 : face powder n03314780
# 3.15 : oboe, hautboy, hautbois n03838899
# 2.80 : lab coat, laboratory coat n03630383
# 2.62 : suit, suit of clothes n04350905
# 1.85 : lipstick, lip rouge n03676483
# 1.73 : loupe, jeweler's loupe n03692522
# ../../data/92_image/animate/5.jpeg 9.13 : wig n04584207
# 8.83 : wool, woolen, woollen n04599235
# 3.93 : face powder n03314780
# 2.40 : chiton, coat-of-mail shell, sea cradle, polyplacophore n01955084
# 2.18 : isopod n01990800
# 2.17 : pick, plectrum, plectron n03929660
# 1.96 : gong, tam-tam n03447721
# 1.80 : trilobite n01768244
# 1.64 : electric ray, crampfish, numbfish, torpedo n01496331
# 1.39 : hair slide n03476684
# ['n04584207', 'n04599235', 'n03314780', 'n01955084', 'n01990800', 'n03929660', 'n03447721', 'n01768244', 'n01496331', 'n03476684']
# 9.13 : wig n04584207
# 8.83 : wool, woolen, woollen n04599235
# 3.93 : face powder n03314780
# 2.40 : chiton, coat-of-mail shell, sea cradle, polyplacophore n01955084
# 2.18 : isopod n01990800
# 2.17 : pick, plectrum, plectron n03929660
# 1.96 : gong, tam-tam n03447721
# 1.80 : trilobite n01768244
# 1.64 : electric ray, crampfish, numbfish, torpedo n01496331
# 1.39 : hair slide n03476684
# ../../data/92_image/animate/38.jpeg 8.95 : Ibizan hound, Ibizan Podenco n02091244
# 3.88 : knot n03627232
# 3.25 : Afghan hound, Afghan n02088094
# 3.14 : gar, garfish, garpike, billfish, Lepisosteus osseus n02641379
# 2.79 : airliner n02690373
# 2.16 : English setter n02100735
# 2.06 : borzoi, Russian wolfhound n02090622
# 1.86 : Bedlington terrier n02093647
# 1.63 : wire-haired fox terrier n02095314
# 1.62 : sturgeon n02640242
# ['n02091244', 'n03627232', 'n02088094', 'n02641379', 'n02690373', 'n02100735', 'n02090622', 'n02093647', 'n02095314', 'n02640242']
# 8.95 : Ibizan hound, Ibizan Podenco n02091244
# 3.88 : knot n03627232
# 3.25 : Afghan hound, Afghan n02088094
# 3.14 : gar, garfish, garpike, billfish, Lepisosteus osseus n02641379
# 2.79 : airliner n02690373
# 2.16 : English setter n02100735
# 2.06 : borzoi, Russian wolfhound n02090622
# 1.86 : Bedlington terrier n02093647
# 1.63 : wire-haired fox terrier n02095314
# 1.62 : sturgeon n02640242
# ../../data/92_image/animate/20.jpeg 55.59 : sunglass n04355933
# 7.51 : sunglasses, dark glasses, shades n04356056
# 4.95 : neck brace n03814639
# 3.85 : sunscreen, sunblock, sun blocker n04357314
# 2.79 : bathing cap, swimming cap n02807133
# 2.64 : Band Aid n02786058
# 2.14 : ski mask n04229816
# 2.07 : loupe, jeweler's loupe n03692522
# 1.66 : mask n03724870
# 1.20 : bearskin, busby, shako n02817516
# ['n04355933', 'n04356056', 'n03814639', 'n04357314', 'n02807133', 'n02786058', 'n04229816', 'n03692522', 'n03724870', 'n02817516']
# 55.59 : sunglass n04355933
# 7.51 : sunglasses, dark glasses, shades n04356056
# 4.95 : neck brace n03814639
# 3.85 : sunscreen, sunblock, sun blocker n04357314
# 2.79 : bathing cap, swimming cap n02807133
# 2.64 : Band Aid n02786058
# 2.14 : ski mask n04229816
# 2.07 : loupe, jeweler's loupe n03692522
# 1.66 : mask n03724870
# 1.20 : bearskin, busby, shako n02817516
# ../../data/92_image/animate/3.jpeg 8.83 : swimming trunks, bathing trunks n04371430
# 4.54 : Band Aid n02786058
# 2.83 : nipple n03825788
# 2.82 : Windsor tie n04591157
# 2.62 : sunscreen, sunblock, sun blocker n04357314
# 2.27 : bathing cap, swimming cap n02807133
# 1.69 : knee pad n03623198
# 1.66 : sarong n04136333
# 1.65 : plastic bag n03958227
# 1.64 : oxygen mask n03868863
# ['n04371430', 'n02786058', 'n03825788', 'n04591157', 'n04357314', 'n02807133', 'n03623198', 'n04136333', 'n03958227', 'n03868863']
# 8.83 : swimming trunks, bathing trunks n04371430
# 4.54 : Band Aid n02786058
# 2.83 : nipple n03825788
# 2.82 : Windsor tie n04591157
# 2.62 : sunscreen, sunblock, sun blocker n04357314
# 2.27 : bathing cap, swimming cap n02807133
# 1.69 : knee pad n03623198
# 1.66 : sarong n04136333
# 1.65 : plastic bag n03958227
# 1.64 : oxygen mask n03868863
# ../../data/92_image/animate/16.jpeg 5.82 : mask n03724870
# 4.95 : neck brace n03814639
# 4.88 : Band Aid n02786058
# 3.50 : face powder n03314780
# 3.40 : ski mask n04229816
# 2.68 : sunscreen, sunblock, sun blocker n04357314
# 2.24 : Windsor tie n04591157
# 2.23 : abaya n02667093
# 1.87 : bolo tie, bolo, bola tie, bola n02865351
# 1.78 : wig n04584207
# ['n03724870', 'n03814639', 'n02786058', 'n03314780', 'n04229816', 'n04357314', 'n04591157', 'n02667093', 'n02865351', 'n04584207']
# 5.82 : mask n03724870
# 4.95 : neck brace n03814639
# 4.88 : Band Aid n02786058
# 3.50 : face powder n03314780
# 3.40 : ski mask n04229816
# 2.68 : sunscreen, sunblock, sun blocker n04357314
# 2.24 : Windsor tie n04591157
# 2.23 : abaya n02667093
# 1.87 : bolo tie, bolo, bola tie, bola n02865351
# 1.78 : wig n04584207

# %%
# Code snippet to get the activation values and saving information{
data = np.array([])

i = 0
result ={}
for layer in model.layers:
    weights = layer.get_weights()
    if len(weights) > 0:
        activations = get_activations(model,i,im)
        if result.get(layer.name, None) is None:
            result[layer.name] = activations[0]
            temp = np.mean(activations[0], axis=0).ravel()
            print layer.name,len(weights),len(activations), activations[0].shape, np.mean(activations[0], axis=0).shape, temp.shape
            data = np.append(data, temp)
    i += 1

fp.close()
with open('../../data/pkl/92_'+str(p)+'_test.pkl', 'wb') as f:
    pickle.dump(data, f)
# Out:
# conv_1 2 1 (48, 96, 55, 55) (96, 55, 55) (290400,)
# conv_2_1 2 1 (48, 128, 27, 27) (128, 27, 27) (93312,)
# conv_2_2 2 1 (48, 128, 27, 27) (128, 27, 27) (93312,)
# conv_3 2 1 (48, 384, 13, 13) (384, 13, 13) (64896,)
# conv_4_1 2 1 (48, 192, 13, 13) (192, 13, 13) (32448,)
# conv_4_2 2 1 (48, 192, 13, 13) (192, 13, 13) (32448,)
# conv_5_1 2 1 (48, 128, 13, 13) (128, 13, 13) (21632,)
# conv_5_2 2 1 (48, 128, 13, 13) (128, 13, 13) (21632,)
# dense_1 2 1 (48, 4096) (4096,) (4096,)
# dense_2 2 1 (48, 4096) (4096,) (4096,)
# dense_3 2 1 (48, 1000) (1000,) (1000,)

# %%
i = 0
result ={}
for layer in model.layers:
    weights = layer.get_weights()
    if len(weights) > 0:
        activations = get_activations(model,i,im)
        if result.get(layer.name, None) is None:
            result[layer.name] = activations[0]
            temp = np.mean(activations[0], axis=0).ravel()
            plt.figure(i+1)
            plt.title(layer.name+' Histogram')
            plt.hist(temp,bins=200)
            #print layer.name,len(weights),len(activations), activations[0].shape, np.mean(activations[0], axis=0).shape, temp.shape
            
    i += 1
